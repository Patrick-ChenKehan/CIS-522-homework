# %%
# !pip install ray
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.2.0-cp38-cp38-manylinux2014_x86_64.whl (57.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray) (3.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from ray) (6.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ray) (2.25.1)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.51.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray) (3.19.6)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray) (22.2.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.1)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray) (7.1.2)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray) (2.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (5.10.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2022.12.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.12.0)
# Installing collected packages: distlib, virtualenv, ray
# Successfully installed distlib-0.3.6 ray-2.2.0 virtualenv-20.17.1

# %%
# from model_factory import create_model

# MNIST:
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor, Compose

# PyTorch:
import torch
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.nn import CrossEntropyLoss

# Other:
from typing import Tuple
from tqdm import tqdm

# %%
_transform_list = [
    ToTensor(),
    lambda x: x.view(-1),
]


def load_data(root='./data') -> Tuple[DataLoader, DataLoader]:
    """
    Get the MNIST data from torchvision.

    Arguments:
        None

    Returns:
        train_loader (DataLoader): The training data loader.
        test_loader (DataLoader): The test data loader.

    """
    # Get the training data:
    train_data = MNIST(
        root=root, train=True, download=True, transform=Compose(_transform_list)
    )
    # Create a data loader for the training data:
    # train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
    # Get the test data:
    test_data = MNIST(
        root=root, train=False, download=True, transform=Compose(_transform_list)
    )
    # Create a data loader for the test data:
    # test_loader = DataLoader(test_data, batch_size=64, shuffle=True)
    # Return the data loaders:
    return train_data, test_data

# %%
import torch
from typing import Callable
import torch.nn as nn


class MLP(nn.Module):
    """MLP class"""

    def __init__(
        self,
        input_size: int,
        hidden_size: int,
        num_classes: int,
        hidden_count: int = 1,
        activation: Callable = torch.nn.ReLU,
        initializer: Callable = torch.nn.init.ones_,
    ) -> None:
        """
        Initialize the MLP.

        Arguments:
            input_size: The dimension D of the input data.
            hidden_size: The number of neurons H in the hidden layer.
            num_classes: The number of classes C.
            activation: The activation function to use in the hidden layer.
            initializer: The initializer to use for the weights.
        """
        super(MLP, self).__init__()

        self.input_size = input_size
        self.num_classes = num_classes
        self.hidden_size = hidden_size
        self.hidden_count = hidden_count
        self.activation = activation()
        self.initializer = initializer
        self.layers = nn.ModuleList()

        for _ in range(hidden_count):
            # next_num_inputs = hidden_size
            layer = nn.Linear(input_size, hidden_size)
            layer.weight = initializer(layer.weight)
            layer.bias = torch.nn.Parameter(torch.tensor(0.0))
            self.layers += [layer, nn.BatchNorm1d(hidden_size), nn.Dropout(0.15)]
            input_size = hidden_size

        # Create final layer
        self.out = nn.Linear(input_size, num_classes)
        self.out.weight = initializer(self.out.weight)
        self.out.bias = torch.nn.Parameter(torch.tensor(0.0))

    def forward(self, x: torch.tensor) -> torch.tensor:
        """
        Forward pass of the network.

        Arguments:
            x: The input data.

        Returns:
            The output of the network.
        """
        # Flatten inputs to 2D (if more than that)
        x = x.flatten(end_dim=-2)

        # Get activations of each layer
        for layer in self.layers:
            if isinstance(layer, nn.Linear):
                x = self.activation(layer(x))
            else:
                x = layer(x)

        # Get outputs
        x = self.out(x)

        return x

# %%
def train_cifar(config, checkpoint_dir=None, data_dir=None):
    net = MLP(784, config['hidden_size'], 10, config['hidden_count'], config['actv'], config['init'])

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.001)

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, testset = load_data(data_dir)

    test_abs = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(
        trainset, [test_abs, len(trainset) - test_abs])

    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=64,
        shuffle=True,
        num_workers=8)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=64,
        shuffle=True,
        num_workers=8)

    for epoch in range(10):  # loop over the dataset multiple times
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1,
                                                running_loss / epoch_steps))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(valloader, 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy=correct / total)
    print("Finished Training")

# %%
def test_accuracy(net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=4, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):
    data_dir = os.path.abspath("./data")
    load_data(data_dir)
    config = {
        "hidden_size": tune.choice([16, 32, 64]),
        "hidden_count": tune.choice([3, 4, 5, 6]),
        "actv": tune.choice([torch.nn.ReLU, torch.nn.Tanh, torch.nn.Sigmoid, torch.nn.PReLU, torch.nn.ELU, torch.nn.Hardswish]),
        "init": tune.choice([torch.nn.init.xavier_normal_, torch.nn.init.kaiming_normal_, torch.nn.init.kaiming_uniform_,
                             torch.nn.init.trunc_normal_, torch.nn.init.orthogonal_])
    }
    scheduler = ASHAScheduler(
        metric="accuracy",
        mode="min",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])
    result = tune.run(
        partial(train_cifar, data_dir=data_dir),
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter=reporter)

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    # best_trained_model = MLP(784, config['hidden_size'], 10, config['hidden_count'], config['actv'], config['init'])
    # device = "cpu"
    # if torch.cuda.is_available():
    #     device = "cuda:0"
    #     if gpus_per_trial > 1:
    #         best_trained_model = nn.DataParallel(best_trained_model)
    # best_trained_model.to(device)

    # best_checkpoint_dir = best_trial.checkpoint.value
    # model_state, optimizer_state = torch.load(os.path.join(
    #     best_checkpoint_dir, "checkpoint"))
    # best_trained_model.load_state_dict(model_state)

    # test_acc = test_accuracy(best_trained_model, device)
    # print("Best trial test set accuracy: {}".format(test_acc))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=10, max_num_epochs=10, gpus_per_trial=0)
# Out:
# 2023-02-05 18:24:39,037	WARNING callback.py:108 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2023-02-05 18:24:39 (running for 00:00:00.19)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 |
# | train_cifar_59dd7_00001 | PENDING  |                   | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |
# | train_cifar_59dd7_00002 | PENDING  |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |
# | train_cifar_59dd7_00003 | PENDING  |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |
# | train_cifar_59dd7_00004 | PENDING  |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |
# | train_cifar_59dd7_00005 | PENDING  |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |
# | train_cifar_59dd7_00006 | PENDING  |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |
# | train_cifar_59dd7_00007 | PENDING  |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |
# | train_cifar_59dd7_00008 | PENDING  |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |
# | train_cifar_59dd7_00009 | PENDING  |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+
# (func pid=18231) /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# (func pid=18231)   warnings.warn(_create_warning_msg(
# == Status ==
# Current time: 2023-02-05 18:24:46 (running for 00:00:07.76)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 |
# | train_cifar_59dd7_00001 | PENDING  |                   | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |
# | train_cifar_59dd7_00002 | PENDING  |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |
# | train_cifar_59dd7_00003 | PENDING  |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |
# | train_cifar_59dd7_00004 | PENDING  |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |
# | train_cifar_59dd7_00005 | PENDING  |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |
# | train_cifar_59dd7_00006 | PENDING  |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |
# | train_cifar_59dd7_00007 | PENDING  |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |
# | train_cifar_59dd7_00008 | PENDING  |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |
# | train_cifar_59dd7_00009 | PENDING  |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  accuracy</th><th>date               </th><th>done  </th><th>episodes_total  </th><th>experiment_id                   </th><th>hostname    </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">    loss</th><th>node_ip    </th><th style="text-align: right;">  pid</th><th>should_checkpoint  </th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>train_cifar_59dd7_00000</td><td style="text-align: right;">  0.89425 </td><td>2023-02-05_18-26-02</td><td>True  </td><td>                </td><td>eac50201129445bcbf41ceb4ddf7d059</td><td>42da89f9997b</td><td style="text-align: right;">                        10</td><td style="text-align: right;">0.362707</td><td>172.28.0.12</td><td style="text-align: right;">18231</td><td>True               </td><td style="text-align: right;">            80.8953 </td><td style="text-align: right;">           7.7648 </td><td style="text-align: right;">      80.8953 </td><td style="text-align: right;"> 1675621562</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                  10</td><td
td><td style="text-align: right;">                         1</td><td style="text-align: right;">0.320679</td><td>172.28.0.12</td><td style="text-align: right;">18231</td><td>True               </td><td style="text-align: right;">             9.0118 </td><td style="text-align: right;">           9.0118 </td><td style="text-align: right;">       9.0118 </td><td style="text-align: right;"> 1675621836</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   1</td><td>59dd7_00006</td><td style="text-align: right;">   0.00348854</td></tr>
# <tr><td>train_cifar_59dd7_00007</td><td style="text-align: right;">  0.63775 </td><td>2023-02-05_18-32-06</td><td>True  </td><td>                </td><td>eac50201129445bcbf41ceb4ddf7d059</td><td>42da89f9997b</td><td style="text-align: right;">                        10</td><td style="text-align: right;">1.02535 </td><td>172.28.0.12</td><td style="text-align: right;">18231</td><td>True               </td><td style="text-align: right;">            90.0812 </td><td style="text-align: right;">           9.07953</td><td style="text-align: right;">      90.0812 </td><td style="text-align: right;"> 1675621926</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                  10</td><td>59dd7_00007</td><td style="text-align: right;">   0.00348854</td></tr>
# <tr><td>train_cifar_59dd7_00008</td><td style="text-align: right;">  0.869417</td><td>2023-02-05_18-33-14</td><td>True  </td><td>                </td><td>eac50201129445bcbf41ceb4ddf7d059</td><td>42da89f9997b</td><td style="text-align: right;">                         8</td><td style="text-align: right;">0.438496</td><td>172.28.0.12</td><td style="text-align: right;">18231</td><td>True               </td><td style="text-
# == Status ==
# Current time: 2023-02-05 18:24:55 (running for 00:00:16.60)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -0.8178333333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.592223 |   0.817833 |                    1 |
# | train_cifar_59dd7_00001 | PENDING  |                   | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |          |            |                      |
# | train_cifar_59dd7_00002 | PENDING  |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |          |            |                      |
# | train_cifar_59dd7_00003 | PENDING  |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00004 | PENDING  |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00005 | PENDING  |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00006 | PENDING  |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00007 | PENDING  |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00008 | PENDING  |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00009 | PENDING  |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:25:03 (running for 00:00:24.37)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -0.8465 | Iter 1.000: -0.8178333333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+---------+------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |    loss |   accuracy |   training_iteration |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+---------+------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.51189 |     0.8465 |                    2 |
# | train_cifar_59dd7_00001 | PENDING  |                   | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |         |            |                      |
# | train_cifar_59dd7_00002 | PENDING  |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |         |            |                      |
# | train_cifar_59dd7_00003 | PENDING  |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |         |            |                      |
# | train_cifar_59dd7_00004 | PENDING  |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |         |            |                      |
# | train_cifar_59dd7_00005 | PENDING  |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |         |            |                      |
# | train_cifar_59dd7_00006 | PENDING  |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |         |            |                      |
# | train_cifar_59dd7_00007 | PENDING  |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |         |            |                      |
# | train_cifar_59dd7_00008 | PENDING  |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |         |            |                      |
# | train_cifar_59dd7_00009 | PENDING  |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |         |            |                      |
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+---------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:25:11 (running for 00:00:32.41)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -0.8465 | Iter 1.000: -0.8178333333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+---------+------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |    loss |   accuracy |   training_iteration |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+---------+------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0
5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.8886666666666667 | Iter 4.000: -0.8686666666666667 | Iter 2.000: -0.8465 | Iter 1.000: -0.8178333333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.372483 |   0.888667 |                    8 |
# | train_cifar_59dd7_00001 | PENDING  |                   | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |          |            |                      |
# | train_cifar_59dd7_00002 | PENDING  |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |          |            |                      |
# | train_cifar_59dd7_00003 | PENDING  |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00004 | PENDING  |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00005 | PENDING  |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00006 | PENDING  |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00007 | PENDING  |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00008 | PENDING  |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00009 | PENDING  |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:25:59 (running for 00:01:20.90)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.8886666666666667 | Iter 4.000: -0.8686666666666667 | Iter 2.000: -0.8465 | Iter 1.000: -0.8178333333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (9 PENDING, 1 RUNNING)
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status   | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00000 | RUNNING  | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.369015 |      0.893 |                    9 |
# | train_cifar_59dd7_00001 | PENDING  |                   | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |          |            |                      |
# | train_cifar_59dd7_00002 | PENDING  |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |          |            |                      |
# | train_cifar_59dd7_00003 | PENDING  |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00004 | PENDING  |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00005 | PENDING  |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00006 | PENDING  |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00007 | PENDING  |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00008 | PENDING  |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00009 | PENDING  |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# +-------------------------+----------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:26:07 (running for 00:01:28.68)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: -0.8886666666666667 | Iter 4.000: -0.8686666666666667 | Iter 2.000: -0.8465 | Iter 1.000: -0.8178333333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (8 PENDING, 1 RUNNING, 1 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00001 | RUNNING    | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 |          |            |                      |
# | train_cifar_59dd7_00002 | PENDING    |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |          |            |                      |
# | train_cifar_59dd7_00003 | PENDING    |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00004 | PENDING    |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00005 | PENDING    |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00006 | PENDING    |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00007 | PENDING    |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00008 | PENDING    |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00009 | PENDING    |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |    0.89425 |                   10 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:26:16 (running for 00:01:37.11)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: -0.8886666666666667 | Iter 4.000: -0.8686666666666667 | Iter 2.000: -0.8465 | Iter 1.000: -0.8084166666666667
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (8 PENDING, 1 RUNNING, 1 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00001 | RUNNING    | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 | 0.669149 |    0.799   |                    1 |
# | train_cifar_59dd7_00002 | PENDING    |                   | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 |          |            |                      |
# | train_cifar_59dd7_00003 | PENDING    |                   | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00004 | PENDING    |                   | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00005 | PENDING    |                   | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00006 | PENDING    |                   | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 |          |            |                      |
# | train_cifar_59dd7_00007 | PENDING    |                   | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00008 | PENDING    |                   | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 |          |            |                      |
# | train_cifar_59dd7_00009 | PENDING    |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |    0.89425 |                   10 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:26:24 (running for 00:01:45.52)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.8886666666666667 | Iter 4.000: -0.8686666666666667 | Iter 2.000: -0.8487083333333334 | Iter 1.000: -0.8084166666666667
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (7 PENDING, 1 RUNNING, 2 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# ...
#
#
# == Status ==
# Current time: 2023-02-05 18:32:54 (running for 00:08:15.48)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: -0.8535 | Iter 4.000: -0.786625 | Iter 2.000: -0.6600833333333334 | Iter 1.000: -0.6685833333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (1 PENDING, 1 RUNNING, 8 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00008 | RUNNING    | 172.28.0.12:18231 | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 | 0.591821 |   0.81725  |                    5 |
# | train_cifar_59dd7_00009 | PENDING    |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |   0.89425  |                   10 |
# | train_cifar_59dd7_00001 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 | 0.529116 |   0.850917 |                    2 |
# | train_cifar_59dd7_00002 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 | 0.512762 |   0.85825  |                   10 |
# | train_cifar_59dd7_00003 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 | 0.401547 |   0.879667 |                    8 |
# | train_cifar_59dd7_00004 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 | 1.31623  |   0.553333 |                   10 |
# | train_cifar_59dd7_00005 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 | 0.417048 |   0.881    |                    1 |
# | train_cifar_59dd7_00006 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 | 0.320679 |   0.901417 |                    1 |
# | train_cifar_59dd7_00007 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 | 1.02535  |   0.63775  |                   10 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:33:02 (running for 00:08:23.68)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: -0.8535 | Iter 4.000: -0.786625 | Iter 2.000: -0.6600833333333334 | Iter 1.000: -0.6685833333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (1 PENDING, 1 RUNNING, 8 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00008 | RUNNING    | 172.28.0.12:18231 | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 | 0.524806 |   0.837917 |                    6 |
# | train_cifar_59dd7_00009 | PENDING    |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |   0.89425  |                   10 |
# | train_cifar_59dd7_00001 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 | 0.529116 |   0.850917 |                    2 |
# | train_cifar_59dd7_00002 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 | 0.512762 |   0.85825  |                   10 |
# | train_cifar_59dd7_00003 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 | 0.401547 |   0.879667 |                    8 |
# | train_cifar_59dd7_00004 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 | 1.31623  |   0.553333 |                   10 |
# | train_cifar_59dd7_00005 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 | 0.417048 |   0.881    |                    1 |
# | train_cifar_59dd7_00006 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 | 0.320679 |   0.901417 |                    1 |
# | train_cifar_59dd7_00007 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 | 1.02535  |   0.63775  |                   10 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:33:11 (running for 00:08:32.39)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 8.000: -0.8535 | Iter 4.000: -0.786625 | Iter 2.000: -0.6600833333333334 | Iter 1.000: -0.6685833333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (1 PENDING, 1 RUNNING, 8 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00008 | RUNNING    | 172.28.0.12:18231 | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 | 0.480253 |   0.8515   |                    7 |
# | train_cifar_59dd7_00009 | PENDING    |                   | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |   0.89425  |                   10 |
# | train_cifar_59dd7_00001 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 | 0.529116 |   0.850917 |                    2 |
# | train_cifar_59dd7_00002 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 | 0.512762 |   0.85825  |                   10 |
# | train_cifar_59dd7_00003 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 | 0.401547 |   0.879667 |                    8 |
# | train_cifar_59dd7_00004 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 | 1.31623  |   0.553333 |                   10 |
# | train_cifar_59dd7_00005 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 | 0.417048 |   0.881    |                    1 |
# | train_cifar_59dd7_00006 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 | 0.320679 |   0.901417 |                    1 |
# | train_cifar_59dd7_00007 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 | 1.02535  |   0.63775  |                   10 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# == Status ==
# Current time: 2023-02-05 18:33:19 (running for 00:08:40.93)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 8.000: -0.8614583333333333 | Iter 4.000: -0.786625 | Iter 2.000: -0.6600833333333334 | Iter 1.000: -0.6685833333333333
# Resources requested: 2.0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (1 RUNNING, 9 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00009 | RUNNING    | 172.28.0.12:18231 | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 |          |            |                      |
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |   0.89425  |                   10 |
# | train_cifar_59dd7_00001 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 | 0.529116 |   0.850917 |                    2 |
# | train_cifar_59dd7_00002 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 | 0.512762 |   0.85825  |                   10 |
# | train_cifar_59dd7_00003 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 | 0.401547 |   0.879667 |                    8 |
# | train_cifar_59dd7_00004 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 | 1.31623  |   0.553333 |                   10 |
# | train_cifar_59dd7_00005 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 | 0.417048 |   0.881    |                    1 |
# | train_cifar_59dd7_00006 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 | 0.320679 |   0.901417 |                    1 |
# | train_cifar_59dd7_00007 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 | 1.02535  |   0.63775  |                   10 |
# | train_cifar_59dd7_00008 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 | 0.438496 |   0.869417 |                    8 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# 2023-02-05 18:33:24,471	INFO tune.py:762 -- Total run time: 525.45 seconds (525.31 seconds for the tuning loop).
# == Status ==
# Current time: 2023-02-05 18:33:24 (running for 00:08:45.32)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 8.000: -0.8614583333333333 | Iter 4.000: -0.786625 | Iter 2.000: -0.6600833333333334 | Iter 1.000: -0.7337916666666666
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects
# Result logdir: /root/ray_results/train_cifar_2023-02-05_18-24-39
# Number of trials: 10/10 (10 TERMINATED)
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
# | Trial name              | status     | loc               | actv                 |   hidden_count |   hidden_size | init                 |     loss |   accuracy |   training_iteration |
# |-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------|
# | train_cifar_59dd7_00000 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              3 |            16 | <function kaimi_db80 | 0.362707 |   0.89425  |                   10 |
# | train_cifar_59dd7_00001 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            16 | <function ortho_dca0 | 0.529116 |   0.850917 |                    2 |
# | train_cifar_59dd7_00002 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              5 |            16 | <function kaimi_dc10 | 0.512762 |   0.85825  |                   10 |
# | train_cifar_59dd7_00003 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_3410 |              4 |            64 | <function trunc_d5e0 | 0.401547 |   0.879667 |                    8 |
# | train_cifar_59dd7_00004 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              5 |            32 | <function trunc_d5e0 | 1.31623  |   0.553333 |                   10 |
# | train_cifar_59dd7_00005 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_9010 |              4 |            32 | <function xavie_da60 | 0.417048 |   0.881    |                    1 |
# | train_cifar_59dd7_00006 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a010 |              4 |            64 | <function xavie_da60 | 0.320679 |   0.901417 |                    1 |
# | train_cifar_59dd7_00007 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_8810 |              6 |            16 | <function trunc_d5e0 | 1.02535  |   0.63775  |                   10 |
# | train_cifar_59dd7_00008 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_a410 |              4 |            32 | <function trunc_d5e0 | 0.438496 |   0.869417 |                    8 |
# | train_cifar_59dd7_00009 | TERMINATED | 172.28.0.12:18231 | <class 'torch.n_f010 |              6 |            32 | <function kaimi_db80 | 0.563269 |   0.83525  |                    1 |
# +-------------------------+------------+-------------------+----------------------+----------------+---------------+----------------------+----------+------------+----------------------+
#
#
# Best trial config: {'hidden_size': 64, 'hidden_count': 4, 'actv': <class 'torch.nn.modules.activation.Hardswish'>, 'init': <function xavier_normal_ at 0x7fdd0d96da60>}
# Best trial final validation loss: 0.32067944295704365
# Best trial final validation accuracy: 0.9014166666666666
